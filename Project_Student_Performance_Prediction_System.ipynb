# %%
import pandas as pd

data = {
    "Student_ID": [
    101, 102, 103, 104, 105,106,
    106, 107, 108, 109, 110,
    111, 112, 113, 114, 115,
    116, 117, 118, 119, 120
    ],
    "Attendance_percentage": [
        95, 87, 72, 96, 68, 91,91, 78, 84, 55, 93,
        74, 88, 62, 97, 80, 90, 70, 85, 58, 92
    ],

    "Previous_sem_marks": [
        88, 76, 65, 92, 58,85,85, 70, 79, 45, 89,
        63, 81, 50, 94, 72, 86, 60, 77, 48, 87
    ],

    "Internal_assessment": [
        91, 82, 70, 94, 62, 88,88, 74, 81, 52, 90,
        68, 85, 56, 96, 76, 89, 64, 80, 51, 91
    ],

    "Assignment_score": [
        90, 78, 68, 95, 60, 86,86, 72, 80, 48, 92,
        65, 83, 54, 95, 75, 87, 62, 79, 50, 89
    ],

    "Study_Hours_Day": [
        6, 5, 3, 7, 2, 6,6, 4, 5, 1, 7,
        3, 5, 2, 8, 4, None, 3, 5, 1, 7
    ],

    "Class_Participation": [
        9, 8, 6, None, 5, 9,9, 7, 8, 3, 10,
        6, 9, 4, 10, 7, 9, 5, 8, 4, 9
    ],

    "Completed_assignments": [
        10, 9, 7, 10, 6, 10,10, 8, 9, 4, 10,
        7, 9, 5, None, 8, 10, 6, 9, 4, 10
    ],

    "Previous_exam_performance": [
        92, 80, 67, 96, 55, 89,89, 71, 82, 42, 94,
        61, 84, 48, 97, 74, 91, 58, 79, 45, 90
    ],

    "Learning_activities": [
        "High", "Low", "Medium", "High", "Low",
        "High","High", "Medium", "High", "Low", "High",
        "Medium", "High", "High", "High", "Medium",
        "High", "Medium", "High", "Low", "High"
    ],

    "Socio_Academic_factors": [
        "Good", "Good", "Average", "Good", "Average",
        "Good","Good", "Average", "Good", "Challenging", "Good",
        "Average", "Good", "Challenging", "Good", "Average",
        "Good", "Average", "Good", "Challenging", "Good"
    ],

    "Final_performance": [
        "Excellent", "Very Good", "Good", "Excellent", "Average",
        "Excellent","Excellent", "Good", "Very Good", "Needs Improvement", "Excellent",
        "Good", "Very Good", "Needs Improvement", "Excellent", "Good",
        "Excellent", "Average", "Very Good", "Needs Improvement", "Excellent"
    ]
}

df = pd.DataFrame(data)
display(df)

display("Head values:",df.head())
display("Tail values:",df.tail())
print("Number of columns and Rows:", df.shape)
display("Datatypes:", df.dtypes)
numerical_cols = df.select_dtypes(include=['number']).columns
display(numerical_cols)
categorical_cols = df.select_dtypes(include=['object']).columns
display(categorical_cols)
display(df.isnull())
display(df.isnull().sum())
df["Study_Hours_Day"] = df["Study_Hours_Day"].fillna(df["Study_Hours_Day"].mean())
df["Class_Participation"] = df["Class_Participation"].fillna(df["Class_Participation"].mean())
df["Completed_assignments"]=df["Completed_assignments"].fillna(df["Completed_assignments"].mean())
df["Previous_exam_performance"] = df["Previous_exam_performance"].fillna(df["Previous_exam_performance"].mean())
display(df)
display("Duplicated values:",df.duplicated())
display(df.duplicated().sum())
df=df.drop_duplicates()
display(df)
print("Count values:",df["Previous_exam_performance"].value_counts())
print("Mean value:",df["Student_ID"].mean())
print("Median value:",df["Attendance_percentage"].median())
print("Mode value:",df["Study_Hours_Day"].mode())
marks_range = df["Class_Participation"].max() - df["Class_Participation"].min()
print("Marks_range",marks_range)
print("Variance",df["Class_Participation"].var())
print("Standard Deviation",df["Class_Participation"].std())
# Out:
#     Student_ID  Attendance_percentage  Previous_sem_marks  \
# 0          101                     95                  88
# 1          102                     87                  76
# 2          103                     72                  65
# 3          104                     96                  92
# 4          105                     68                  58
# 5          106                     91                  85
# 6          106                     91                  85
# 7          107                     78                  70
# 8          108                     84                  79
# 9          109                     55                  45
# 10         110                     93                  89
# 11         111                     74                  63
# 12         112                     88                  81
# 13         113                     62                  50
# 14         114                     97                  94
# ...
